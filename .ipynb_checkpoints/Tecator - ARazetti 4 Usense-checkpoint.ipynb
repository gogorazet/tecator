# %% [markdown]
# ## Fetch data

# %% [markdown]
# ### Imports

# %%
import arff, numpy as np
import math
import pandas as pd
import matplotlib 
from matplotlib import cm
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn import datasets, linear_model, metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Read data

# %%
dataset = pd.read_csv('csvtecator_simplified_header.csv')
dataset.info()
dataset.head(240)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Columns: 126 entries, id to protein
# dtypes: float64(125), int64(1)
# memory usage: 236.4 KB
#       id       _1       _2       _3       _4       _5       _6       _7  \
# 0      1  2.61776  2.61814  2.61859  2.61912  2.61981  2.62071  2.62186
# 1      2  2.83454  2.83871  2.84283  2.84705  2.85138  2.85587  2.86060
# 2      3  2.58284  2.58458  2.58629  2.58808  2.58996  2.59192  2.59401
# 3      4  2.82286  2.82460  2.82630  2.82814  2.83001  2.83192  2.83392
# 4      5  2.78813  2.78989  2.79167  2.79350  2.79538  2.79746  2.79984
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 235  236  3.22518  3.23016  3.23505  3.23988  3.24476  3.24971  3.25472
# 236  237  3.30792  3.31259  3.31733  3.32205  3.32683  3.33169  3.33663
# 237  238  2.66103  2.66344  2.66582  2.66820  2.67065  2.67321  2.67588
# 238  239  3.02438  3.02997  3.03550  3.04102  3.04653  3.05209  3.05769
# 239  240  3.32499  3.33198  3.33895  3.34587  3.35275  3.35968  3.36673
#
#           _8       _9  ...  principal_component_16  principal_component_17  \
# 0    2.62334  2.62511  ...                0.233876                0.899661
# 1    2.86566  2.87093  ...               -0.195980               -0.046359
# 2    2.59627  2.59873  ...                0.795466                0.762246
# 3    2.83606  2.83842  ...                0.616500               -0.388684
# 4    2.80254  2.80553  ...               -1.095540               -1.348450
# ..       ...      ...  ...                     ...                     ...
# 235  3.25980  3.26498  ...               -0.897510               -1.094940
# 236  3.34170  3.34700  ...               -1.033330               -1.196250
# 237  2.67864  2.68160  ...                0.413767                0.500473
# 238  3.06330  3.06903  ...               -0.250646               -0.298301
# 239  3.37386  3.38113  ...               -1.494400               -1.082530
#
#      principal_component_18  principal_component_19  principal_component_20  \
# 0                 -0.042006                0.708717               -0.254173
# 1                 -0.634996               -0.354403                0.014650
# 2                 -1.268580                0.690588               -0.785592
# 3                 -2.068390                1.276160               -0.259437
# 4                  0.453559                0.402624                0.031307
# ..                      ...                     ...                     ...
# 235               -0.047774               -1.072080                0.683963
# 236                0.991593               -0.987896                0.813800
# 237               -0.232210                0.160583               -0.456995
# 238               -0.223632               -0.436276                0.372878
# 239                0.798304               -1.252180                1.245670
#
#      principal_component_21  principal_component_22  moisture   fat  protein
# 0                 -0.391579               -0.419313      60.5  22.5     16.7
# 1                  0.269542                0.096692      46.0  40.1     13.5
# 2                 -0.671237               -0.710290      71.0   8.4     20.5
# 3                 -0.140206               -0.165963      72.8   5.9     20.7
# 4                  0.021824                0.145777      58.3  25.5     15.5
# ..                      ...                     ...       ...   ...      ...
# 235                0.743673                0.824097      70.0   6.6     23.2
# 236                0.919915                0.950013      69.7   7.1     23.2
# 237               -0.425684               -0.438117      69.1   7.7     22.9
# 238                0.288446                0.383060      66.3  10.4     22.4
# 239                1.284390                1.229940      65.2  12.3     22.5
#
# [240 rows x 126 columns]

# %% [markdown]
# ### Create test and train sets

# %%
train_pc = dataset[0:172]
test_pc = dataset[172:215]
test_extrapolated_pc = dataset[215:240]

print('length train = ', len(train_pc), ' length test = ', len(test_pc), 
      ' length extrapolated = ', len(test_extrapolated_pc))
# Out:
# length train =  172  length test =  43  length extrapolated =  25

# %% [markdown]
# ## Take a look at data

# %% [markdown]
# ### Target distributions

# %%
# check target distribution - train
plt.hist(train_pc['fat'])
plt.title('Fat % distribution - Training set')
plt.show()

# check target distribution - test
plt.hist(test_pc['fat'])
plt.title('Fat % distribution - Test set')
plt.show()

# check target distribution - extrapolated
plt.hist(test_extrapolated_pc['fat'])
plt.title('Fat % distribution - Extrapolated set')
plt.show()

# %% [markdown]
# ### Check consistency

# %%
# Are meat components in %?
sum_components = train_pc['fat'] + train_pc['protein'] + train_pc['moisture']
s_c = sum_components.to_frame(name = 'tot')

plt.plot(s_c)
plt.xlabel('Data points')
plt.ylabel('Protein + Fat + Moisture (%)')

print('Frequency of tot > 100% = ',round(sum(s_c.tot>100)/len(s_c.tot),2))
print('Frequency of tot < 99% = ',round(sum(s_c.tot<97)/len(s_c.tot),2))
# Out:
# Frequency of tot > 100% =  0.14
# Frequency of tot < 99% =  0.11

# %% [markdown]
# ### Reconstruct some spectra

# %%
#Low fat - < 10
low_fat = dataset[11:12]
low_fat_spectrum = low_fat.iloc[:,1:101]
low_fat2 = dataset[12:13]
low_fat_spectrum2 = low_fat2.iloc[:,1:101]
low_fat3 = dataset[15:16]
low_fat_spectrum3 = low_fat3.iloc[:,1:101]


#Medium fat - 10 - 30
medium_fat = dataset[159:160]
medium_fat_spectrum = medium_fat.iloc[:,1:101]
medium_fat2 = dataset[31:32]
medium_fat_spectrum2 = medium_fat2.iloc[:,1:101]
medium_fat3 = dataset[37:38]
medium_fat_spectrum3 = medium_fat3.iloc[:,1:101]


#High fat - 43 - 58.5
high_fat = dataset[41:42]
high_fat_spectrum = high_fat.iloc[:,1:101]
high_fat2 = dataset[172:173]
high_fat_spectrum2 = high_fat2.iloc[:,1:101]
high_fat3 = dataset[222:223]
high_fat_spectrum3 = high_fat3.iloc[:,1:101]

# ---------------

#Plotting
plt.plot(low_fat_spectrum.T, c=(0, 0, 0.5), label= low_fat.fat.values[0])
plt.plot(low_fat_spectrum2.T, c=(0, 0, 0.7), label= low_fat2.fat.values[0])
plt.plot(low_fat_spectrum3.T, c=(0, 0, 0.9), label= low_fat3.fat.values[0])

plt.plot(medium_fat_spectrum.T, c=(0, 0.5, 0), label=medium_fat.fat.values[0])
plt.plot(medium_fat_spectrum2.T, c=(0, 0.7, 0), label=medium_fat2.fat.values[0])
plt.plot(medium_fat_spectrum3.T, c=(0, 0.9, 0), label=medium_fat3.fat.values[0])

plt.plot(high_fat_spectrum.T,  c=(0.5, 0, 0), label=high_fat.fat.values[0])
plt.plot(high_fat_spectrum2.T,  c=(0.7, 0, 0), label=high_fat2.fat.values[0])
plt.plot(high_fat_spectrum3.T,  c=(0.9, 0, 0), label=high_fat3.fat.values[0])

plt.title('Varied fat % spectra')
plt.xlabel('Wavelength')
plt.ylabel('Absorbance')

plt.legend()
plt.show()

# %% [markdown]
# ### Feature creation

# %%
#max linear corr channel
plt.scatter(train_pc['_41'], train_pc['fat'], label = 'Channel 41')

#peak detector
train_pc = train_pc.assign(peak_43_50=lambda x: x['_43'] - x['_50'])
plt.scatter(train_pc['peak_43_50'], train_pc['fat'], label = 'Regular peak')

#peak ratio
train_pc = train_pc.assign(ratio_43_50=lambda x: (x['_43'] - x['_50']/x['_43']))
plt.scatter(train_pc['ratio_43_50'], train_pc['fat'], label = 'Peak ratio')

#peak normalized
train_pc = train_pc.assign(peak_43_1=lambda x: x['_43'] - x['_1'])
plt.scatter(train_pc['peak_43_1'], train_pc['fat'], label = 'Peak normalized')

plt.legend()
plt.xlabel('Feature value')
plt.ylabel('Fat %')
# Out:
# Text(0, 0.5, 'Fat %')

# %% [markdown]
# ### Check visually general correlations

# %%
sn.pairplot(train_pc, vars=['_1', '_40', '_41'
                                ,'moisture', 'protein', 'fat'], kind='reg')

# %% [markdown]
# ### Check correlation matrix

# %%
corr_matrix = train_pc.corr()
corr_matrix.fat.to_csv('correlation_matrix_fat.csv')
corr_matrix.to_csv('correlation_matrix_all.csv')

# %% [markdown]
# # Modelling

# %%
# Eval function
def SEP(real_y, pred_y):
    error = math.sqrt(mean_squared_error(real_y,pred_y))
    print(error)

# %% [markdown]
# ## Linear regressions

# %% [markdown]
# ### Linear regression - Peak detector

# %%
# Add peak detector to test data
test_pc = test_pc.assign(peak_43_50=lambda x: x['_43'] - x['_50'])
test_pc = test_pc.assign(ratio_43_50=lambda x: (x['_43'] - x['_50']/x['_43']))

X = train_pc[['peak_43_50']]
Y = train_pc[['fat']]
reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['peak_43_50']]
Y_test = test_pc[['fat']]

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.7497727650731423
# result SEP =
# 5.223279847370223
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - Best PC

# %%
X = train_pc[['principal_component_3']]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['principal_component_3']]
Y_test = test_pc[['fat']]

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.34008380034474817
# result SEP =
# 10.732047598394454
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - Best channel

# %%
X = train_pc[['_41']]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['_41']]
Y_test = test_pc[['fat']]

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.29973050624113073
# result SEP =
# 12.008111992186615
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - All 3 combined

# %%
X = train_pc[['_41','peak_43_50','principal_component_3']]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['_41','peak_43_50','principal_component_3']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.7955968940779894
# result SEP =
# 5.4157313868242225
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - multiple PC

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ]]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
                 ]]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.9601298414509136
# result SEP =
# 2.595155929751851
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - multiple PC + 2 main features <-- Best

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_41'
             ,'peak_43_50'
             ,'ratio_43_50'
             ]]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_41'
             ,'peak_43_50'
             ,'ratio_43_50'
                 ]]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.974295229254297
# result SEP =
# 2.125937033367772
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Linear regression - all PC

# %%
X = train_pc.iloc[:,101:123]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(X, Y)

X_test = test_pc.iloc[:,101:123]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# result SEP =
# 4.363191553769296
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/4135513732.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ## Trees

# %% [markdown]
# ### Main PC

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12']]
Y = train_pc[['fat']]

reg = DecisionTreeRegressor(max_depth=20)
reg.fit(X, Y)

X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# result SEP =
# 3.7931088065865777
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### 2 features

# %%
X = train_pc[['_1','peak_43_50']]
Y = train_pc[['fat']]

reg = DecisionTreeRegressor(max_depth=10)
reg.fit(X, Y)

X_test = test_pc[['_1','peak_43_50']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# result SEP =
# 4.869311460630312
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Main PC + 2 features

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_1','peak_43_50','ratio_43_50']]
Y = train_pc[['fat']]

reg = DecisionTreeRegressor(max_depth=9)
reg.fit(X, Y)

X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_1','peak_43_50','ratio_43_50']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# result SEP =
# 3.39577678149727
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ## Random forest

# %% [markdown]
# ### Main PC

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12']]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 500, random_state = 0)
reg.fit(X, Y)

X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/1026548701.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# result SEP =
# 4.366238605694888
# Text(0, 0.5, 'Predicted values - fat %')

# %%
X = train_pc[['_1','peak_43_50']]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 500, random_state = 0)
reg.fit(X, Y)

X_test = test_pc[['_1','peak_43_50']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/2592543322.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# result SEP =
# 4.475757142963724
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Main PC + 2 features

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_1'
             ,'peak_43_50'
             ,'ratio_43_50']]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 500, random_state = 0)
reg.fit(X, Y)

X_test = test_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_1'
             ,'peak_43_50'
             ,'ratio_43_50']]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/3685178000.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# result SEP =
# 2.589549788292663
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Just everybody - channels

# %%
X = train_pc.iloc[:,1:101]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(X, Y)

X_test = test_pc.iloc[:,1:101]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/157313021.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# result SEP =
# 7.600856198711328
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Just everybody - PCA

# %%
X = train_pc.iloc[:,101:123]
Y = train_pc[['fat']]

reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(X, Y)

X_test = test_pc.iloc[:,101:123]
Y_test = test_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# result SEP =
# 4.363191553769296
# /var/folders/y2/ks7x_gtj541_fm6dsv5wqcn80000gn/T/ipykernel_70765/4135513732.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(X, Y)
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ## Extrapolated data model comparison

# %% [markdown]
# ### Best model

# %%
# Add peak detector to extrapolated data
test_extrapolated_pc = test_extrapolated_pc.assign(peak_43_50=lambda x: x['_43'] - x['_50'])
test_extrapolated_pc = test_extrapolated_pc.assign(ratio_43_50=lambda x: (x['_43'] - x['_50']/x['_43']))

X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_41'
             ,'peak_43_50'
             ,'ratio_43_50'
             ]]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_extrapolated_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ,'principal_component_11','principal_component_12'
             ,'_41'
             ,'peak_43_50'
             ,'ratio_43_50'
                 ]]
Y_test = test_extrapolated_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.974295229254297
# result SEP =
# 3.4972416411625544
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ### Liear with 10 PC

# %%
X = train_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
             ]]
Y = train_pc[['fat']]

reg = LinearRegression().fit(X,Y)
print('regr. score = ', reg.score(X,Y))


X_test = test_extrapolated_pc[['principal_component_1','principal_component_2','principal_component_3','principal_component_4','principal_component_5'
             ,'principal_component_6','principal_component_7','principal_component_8','principal_component_9','principal_component_10'
                 ]]
Y_test = test_extrapolated_pc['fat']

Y_pred = reg.predict(X_test)

print('result SEP = ')
SEP(Y_test, Y_pred)

plt.scatter(Y_test, Y_pred)
plt.xlabel('Real values - fat %')
plt.ylabel('Predicted values - fat %')
# Out:
# regr. score =  0.9526568447960592
# result SEP =
# 6.538657031086598
# Text(0, 0.5, 'Predicted values - fat %')

# %% [markdown]
# ## Other component features

# %%
# Reconstruct some spectra - Moisture
#Low  
low_moisture2 = dataset[219:220]
low_moisture_spectrum2 = low_moisture2.iloc[:,1:101]
low_moisture3 = dataset[215:216]
low_moisture_spectrum3 = low_moisture3.iloc[:,1:101]

#High  
high_moisture2 = dataset[172:173]
high_moisture_spectrum2 = high_moisture2.iloc[:,1:101]
high_moisture3 = dataset[144:145]
high_moisture_spectrum3 = high_moisture3.iloc[:,1:101]

# ---------------

#Plotting

plt.plot(low_moisture_spectrum2.T, c=(0, 0, 0.7), label= low_moisture2.moisture.values[0])
plt.plot(low_moisture_spectrum3.T, c=(0, 0, 0.9), label= low_moisture3.moisture.values[0])

plt.plot(high_moisture_spectrum2.T,  c=(0.7, 0, 0), label=high_moisture2.moisture.values[0])
plt.plot(high_moisture_spectrum3.T,  c=(0.9, 0, 0), label=high_moisture3.moisture.values[0])

plt.legend()
plt.title('Varied moisture % spectra')
plt.xlabel('Wavelength')
plt.ylabel('Absorbance')
plt.show()

# %%
# Reconstruct some spectra - Protein
#Low  
low_moisture2 = dataset[220:221]
low_moisture_spectrum2 = low_moisture2.iloc[:,1:101]
low_moisture3 = dataset[209:210]
low_moisture_spectrum3 = low_moisture3.iloc[:,1:101]

#High  
high_moisture2 = dataset[8:9]
high_moisture_spectrum2 = high_moisture2.iloc[:,1:101]
high_moisture3 = dataset[3:4]
high_moisture_spectrum3 = high_moisture3.iloc[:,1:101]

# ---------------

#Plotting

plt.plot(low_moisture_spectrum2.T, c=(0, 0, 0.7), label= low_moisture2.protein.values[0])
plt.plot(low_moisture_spectrum3.T, c=(0, 0, 0.9), label= low_moisture3.protein.values[0])

plt.plot(high_moisture_spectrum2.T,  c=(0.7, 0, 0), label=high_moisture2.protein.values[0])
plt.plot(high_moisture_spectrum3.T,  c=(0.9, 0, 0), label=high_moisture3.protein.values[0])

plt.legend()
plt.title('Varied protein % spectra')
plt.xlabel('Wavelength')
plt.ylabel('Absorbance')
plt.show()
